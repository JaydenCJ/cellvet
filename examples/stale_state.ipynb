# %% [markdown]
# # Quarterly revenue analysis
#
# This notebook *looks* fine and its saved outputs are real —
# but it only ever ran against stale kernel state.

# %%
mean_revenue = statistics.mean(revenue)
mean_revenue
# Out:
# 1237.5

# %%
import statistics

revenue = [1200, 1350, 980, 1420]

# %%
tax_rate = 0.10

# %%
total = mean_revenue * (1 + tax_rate)
round(total, 2)
# Out:
# 1546.88

# %% [markdown]
# Re-ran the rate cell while experimenting:

# %%
tax_rate = 0.25

# %%
report = build_report(revenue, total)
